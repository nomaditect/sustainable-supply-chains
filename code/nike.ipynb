# %% [markdown]
# # a geospatial data story about nike
# by simon stewart dec 21

# %% [markdown]
# ## assemble tools

# %%
import pandas as pd
import geopandas as gpd
import geopy

# %% [markdown]
# ## import data

# %%
#world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
nike = pd.read_excel('/Users/AFROARC/Documents/GitHub/final_project/data/Nike Factory Locations.xlsx')

# %%
nike
# Out:
#                                           Factory Name    Factory Type  \
# 0                                  A & K DESIGNS, INC.  FINISHED GOODS
# 1                               A. FIRST VINA CO. LTD.  FINISHED GOODS
# 2                     ACABADOS Y SERIGRAFIA, SA (ACSA)  FINISHED GOODS
# 3                               ADORA FOOTWEAR LIMITED  FINISHED GOODS
# 4                                        AJARA TEXTILE  FINISHED GOODS
# ..                                                 ...             ...
# 613                  ZHENJIANG TUNTEX GARMENT CO; LTD.  FINISHED GOODS
# 614  ZHIJIE FOOTWEAR TECHNICAL SERVICE(ZHONGSHAN)CO...  FINISHED GOODS
# 615  ZHONGSHAN CITY SANXIANG HENG LONG GARMENT FACT...  FINISHED GOODS
# 616                  ZHONGSHAN WEI LI TEXTILE CO.,LTD.  FINISHED GOODS
# 617         ZHUJI HENGTAI KNITTING & TEXTILE CO., LTD.  FINISHED GOODS
#
#     Product Type Nike, Inc. Brand(s)      Events          Supplier Group  \
# ...

# %%
nike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Factory Name         618 non-null    object
#  1   Factory Type         618 non-null    object
#  2   Product Type         618 non-null    object
#  3   Nike, Inc. Brand(s)  618 non-null    object
#  4   Events               112 non-null    object
#  5   Supplier Group       618 non-null    object
#  6   Address              618 non-null    object
#  7   City                 616 non-null    object
#  8   State                582 non-null    object
#  9   Postal Code          543 non-null    object
#  10  Country              618 non-null    object
#  11  Operating Region     0 non-null      float64
#  12  Total Workers        542 non-null    float64
#  13  Line Workers         539 non-null    float64
#  14  % Female Workers     618 non-null    float64
# ...

# %%
nike.describe()
# Out:
#        Operating Region  Total Workers  Line Workers  % Female Workers  \
# count               0.0     542.000000    539.000000        618.000000
# mean                NaN    1887.490775   1567.506494          0.592152
# std                 NaN    3403.533767   2962.633616          0.291402
# min                 NaN       4.000000      3.000000          0.000000
# 25%                 NaN     116.500000     90.500000          0.470000
# 50%                 NaN     662.500000    501.000000          0.670000
# 75%                 NaN    2043.750000   1548.000000          0.820000
# max                 NaN   24732.000000  23600.000000          1.000000
#
#        % Migrant Workers
# count         618.000000
# mean            0.074353
# std             0.210034
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.003750
# max             1.000000

# %% [markdown]
# ## convert address to lat long

# %%
nike.head(1)
# Out:
#           Factory Name    Factory Type Product Type Nike, Inc. Brand(s)  \
# 0  A & K DESIGNS, INC.  FINISHED GOODS      APPAREL                NIKE
#
#        Events Supplier Group             Address      City   State  \
# 0  Collegiate  A & K DESIGNS  8325 SE HARNEY ST.  PORTLAND  OREGON
#
#   Postal Code  ... Operating Region  Total Workers  Line Workers  \
# 0       97266  ...              NaN           94.0          82.0
#
#    % Female Workers  % Migrant Workers  Contact Name Contact Phone  \
# 0              0.69                0.0      Paul Lee  503-238-6514
#
#     Contact Fax              Contact Email Subcons
# 0  877-968-2889  paul.lee@akdesignsinc.com     NaN
#
# [1 rows x 21 columns]
